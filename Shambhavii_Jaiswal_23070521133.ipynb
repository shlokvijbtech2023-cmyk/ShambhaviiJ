# %% [markdown]
# # House Price Prediction
#
# **Name:** Shambhavii Jaiswal
#
# **PRN:** 23070521133

# %%
from IPython.display import Image, display
display(Image(filename='Screenshot 2026-07-28 at 12.15.24.png', width=700))
# Out:
# <Training curve image inserted>

# %% [markdown]
# Training curve inserted for presentation.
